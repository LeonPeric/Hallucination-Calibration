# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
run_0 = pd.read_csv('../src/experiment/training_logs/run_0_training_log.txt', sep=' ')

# %%
ax = run_0['Loss'].plot(figsize=(10, 6))
ax.set_xlabel('Iteration')
ax.set_ylabel('Loss')
plt.savefig('../assets/loss_plot.png', dpi=300)
plt.show()

# %%
run_1 = pd.read_csv('../src/experiment/training_logs/run_10_training_log.txt', sep=' ')

# %%
run_1['Loss'].plot()
# Out:
# <Axes: >
