# %%
import json
import pandas as pd
import numpy as np
import os

# %%
run_configs = []
with open("../src/experiment/run_configs/run_configs.json","r") as f:
    for line in f:
        run_configs.append(json.loads(line))

# %%
os.getcwd()
# Out:
# 'C:\\Users\\Batu\\Documents\\GitHub\\Hallucination-Calibration\\demos'

# %%
run_configs
# Out:
# [{'run_number': 0,
#   'seed': 42,
#   'zipf_alpha': 0.1,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 1,
#   'seed': 42,
#   'zipf_alpha': 0.1,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 2,
#   'seed': 42,
#   'zipf_alpha': 0.1,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 3,
#   'seed': 42,
#   'zipf_alpha': 0.1,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 4,
#   'seed': 42,
#   'zipf_alpha': 0.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 5,
#   'seed': 42,
#   'zipf_alpha': 0.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 6,
#   'seed': 42,
#   'zipf_alpha': 0.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 7,
#   'seed': 42,
#   'zipf_alpha': 0.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 8,
#   'seed': 42,
#   'zipf_alpha': 1.0,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 9,
#   'seed': 42,
#   'zipf_alpha': 1.0,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 10,
#   'seed': 42,
#   'zipf_alpha': 1.0,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 11,
#   'seed': 42,
#   'zipf_alpha': 1.0,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 12,
#   'seed': 42,
#   'zipf_alpha': 1.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 13,
#   'seed': 42,
#   'zipf_alpha': 1.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 14,
#   'seed': 42,
#   'zipf_alpha': 1.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 15,
#   'seed': 42,
#   'zipf_alpha': 1.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 16,
#   'seed': 42,
#   'zipf_alpha': 2,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 17,
#   'seed': 42,
#   'zipf_alpha': 2,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 18,
#   'seed': 42,
#   'zipf_alpha': 2,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 19,
#   'seed': 42,
#   'zipf_alpha': 2,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 20,
#   'seed': 15,
#   'zipf_alpha': 0.1,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 21,
#   'seed': 15,
#   'zipf_alpha': 0.1,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 22,
#   'seed': 15,
#   'zipf_alpha': 0.1,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 23,
#   'seed': 15,
#   'zipf_alpha': 0.1,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 24,
#   'seed': 15,
#   'zipf_alpha': 0.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 25,
#   'seed': 15,
#   'zipf_alpha': 0.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 26,
#   'seed': 15,
#   'zipf_alpha': 0.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 27,
#   'seed': 15,
#   'zipf_alpha': 0.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 28,
#   'seed': 15,
#   'zipf_alpha': 1.0,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 29,
#   'seed': 15,
#   'zipf_alpha': 1.0,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 30,
#   'seed': 15,
#   'zipf_alpha': 1.0,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 31,
#   'seed': 15,
#   'zipf_alpha': 1.0,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 32,
#   'seed': 15,
#   'zipf_alpha': 1.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 33,
#   'seed': 15,
#   'zipf_alpha': 1.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 34,
#   'seed': 15,
#   'zipf_alpha': 1.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 35,
#   'seed': 15,
#   'zipf_alpha': 1.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 36,
#   'seed': 15,
#   'zipf_alpha': 2,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 37,
#   'seed': 15,
#   'zipf_alpha': 2,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 38,
#   'seed': 15,
#   'zipf_alpha': 2,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 39,
#   'seed': 15,
#   'zipf_alpha': 2,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 40,
#   'seed': 102,
#   'zipf_alpha': 0.1,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 41,
#   'seed': 102,
#   'zipf_alpha': 0.1,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 42,
#   'seed': 102,
#   'zipf_alpha': 0.1,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 43,
#   'seed': 102,
#   'zipf_alpha': 0.1,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 44,
#   'seed': 102,
#   'zipf_alpha': 0.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 45,
#   'seed': 102,
#   'zipf_alpha': 0.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 46,
#   'seed': 102,
#   'zipf_alpha': 0.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 47,
#   'seed': 102,
#   'zipf_alpha': 0.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 48,
#   'seed': 102,
#   'zipf_alpha': 1.0,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 49,
#   'seed': 102,
#   'zipf_alpha': 1.0,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 50,
#   'seed': 102,
#   'zipf_alpha': 1.0,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 51,
#   'seed': 102,
#   'zipf_alpha': 1.0,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 52,
#   'seed': 102,
#   'zipf_alpha': 1.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 53,
#   'seed': 102,
#   'zipf_alpha': 1.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 54,
#   'seed': 102,
#   'zipf_alpha': 1.5,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 55,
#   'seed': 102,
#   'zipf_alpha': 1.5,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000},
#  {'run_number': 56,
#   'seed': 102,
#   'zipf_alpha': 2,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 100,
#   'possibilities_size': 101000},
#  {'run_number': 57,
#   'seed': 102,
#   'zipf_alpha': 2,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_small.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 101000},
#  {'run_number': 58,
#   'seed': 102,
#   'zipf_alpha': 2,
#   'training_size': 800,
#   'true_dist_size': 1000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 100,
#   'possibilities_size': 311000},
#  {'run_number': 59,
#   'seed': 102,
#   'zipf_alpha': 2,
#   'training_size': 8000,
#   'true_dist_size': 10000,
#   'food_list_name': 'food_list_medium.txt',
#   'number_of_person': 1000,
#   'possibilities_size': 311000}]

# %%
config_df = pd.DataFrame(run_configs)
config_df.set_index("run_number", inplace=True)

# %%
config_df.head(10)
# Out:
#             seed  zipf_alpha  training_size  true_dist_size  \
# run_number
# 0             42         0.1            800            1000
# 1             42         0.1           8000           10000
# 2             42         0.1            800            1000
# 3             42         0.1           8000           10000
# 4             42         0.5            800            1000
# 5             42         0.5           8000           10000
# 6             42         0.5            800            1000
# 7             42         0.5           8000           10000
# 8             42         1.0            800            1000
# 9             42         1.0           8000           10000
#
#                   food_list_name  number_of_person  possibilities_size
# run_number
# 0            food_list_small.txt               100              101000
# 1            food_list_small.txt              1000              101000
# 2           food_list_medium.txt               100              311000
# 3           food_list_medium.txt              1000              311000
# 4            food_list_small.txt               100              101000
# 5            food_list_small.txt              1000              101000
# 6           food_list_medium.txt               100              311000
# 7           food_list_medium.txt              1000              311000
# 8            food_list_small.txt               100              101000
# 9            food_list_small.txt              1000              101000

# %%
results = []
with open("../src/experiment/results/results.json","r") as f:
    for line in f:
        results.append(json.loads(line))

# %%
results_df = pd.DataFrame(results)
results_df.set_index("run", inplace=True)

# %%
results_df.head()
# Out:
#      monofact_rate  miscalibration_rate  \
# run
# 0          0.99500             0.452007
# 1          0.92400             0.912587
# 2          1.00000             0.437080
# 3          0.97575             0.923799
# 4          0.97750             0.447000
#
#      facts_to_possible_hallucinations_ratio  estimated_hallucinations_rate  \
# run
# 0                                  0.374529                      -0.079023
# 1                                  0.036065                      -0.102914
# 2                                  0.375469                      -0.060037
# 3                                  0.037045                      -0.063356
# 4                                  0.371240                      -0.088227
#
#      naive_hallucinations_rate  true_hallucinations_rate
# run
# 0                        0.027                     0.027
# 1                        0.157                     0.156
# 2                        0.028                     0.028
# 3                        0.197                     0.197
# 4                        0.026                     0.026

# %%
merged_results_df = pd.merge(config_df,results_df,left_index=True,right_index=True)

# %%
merged_results_df
# Out:
#             seed  zipf_alpha  training_size  true_dist_size  \
# run_number
# 0             42         0.1            800            1000
# 1             42         0.1           8000           10000
# 2             42         0.1            800            1000
# 3             42         0.1           8000           10000
# 4             42         0.5            800            1000
# 5             42         0.5           8000           10000
# 6             42         0.5            800            1000
# 7             42         0.5           8000           10000
# 8             42         1.0            800            1000
# 9             42         1.0           8000           10000
# 10            42         1.0            800            1000
# 11            42         1.0           8000           10000
# 12            42         1.5            800            1000
# 13            42         1.5           8000           10000
# 14            42         1.5            800            1000
# 15            42         1.5           8000           10000
# 16            42         2.0            800            1000
# 17            42         2.0           8000           10000
# 18            42         2.0            800            1000
# 19            42         2.0           8000           10000
# 20            15         0.1            800            1000
# 21            15         0.1           8000           10000
# 22            15         0.1            800            1000
# 23            15         0.1           8000           10000
# 24            15         0.5            800            1000
# 25            15         0.5           8000           10000
# 26            15         0.5            800            1000
# 27            15         0.5           8000           10000
# 28            15         1.0            800            1000
# 29            15         1.0           8000           10000
# 30            15         1.0            800            1000
# 31            15         1.0           8000           10000
# 32            15         1.5            800            1000
# 33            15         1.5           8000           10000
# 34            15         1.5            800            1000
# 35            15         1.5           8000           10000
# 36            15         2.0            800            1000
# 37            15         2.0           8000           10000
# 38            15         2.0            800            1000
# 39            15         2.0           8000           10000
# 40           102         0.1            800            1000
# 41           102         0.1           8000           10000
# 42           102         0.1            800            1000
# 43           102         0.1           8000           10000
# 44           102         0.5            800            1000
# 45           102         0.5           8000           10000
# 46           102         0.5            800            1000
# 47           102         0.5           8000           10000
# 48           102         1.0            800            1000
# 49           102         1.0           8000           10000
# 50           102         1.0            800            1000
# 51           102         1.0           8000           10000
# 52           102         1.5            800            1000
# 53           102         1.5           8000           10000
# 54           102         1.5            800            1000
# 55           102         1.5           8000           10000
# 56           102         2.0            800            1000
# 57           102         2.0           8000           10000
# 58           102         2.0            800            1000
# 59           102         2.0           8000           10000
#
#                   food_list_name  number_of_person  possibilities_size  \
# run_number
# 0            food_list_small.txt               100              101000
# 1            food_list_small.txt              1000              101000
# 2           food_list_medium.txt               100              311000
# 3           food_list_medium.txt              1000              311000
# 4            food_list_small.txt               100              101000
# 5            food_list_small.txt              1000              101000
# 6           food_list_medium.txt               100              311000
# 7           food_list_medium.txt              1000              311000
# 8            food_list_small.txt               100              101000
# 9            food_list_small.txt              1000              101000
# 10          food_list_medium.txt               100              311000
# 11          food_list_medium.txt              1000              311000
# 12           food_list_small.txt               100              101000
# 13           food_list_small.txt              1000              101000
# 14          food_list_medium.txt               100              311000
# 15          food_list_medium.txt              1000              311000
# 16           food_list_small.txt               100              101000
# 17           food_list_small.txt              1000              101000
# 18          food_list_medium.txt               100              311000
# 19          food_list_medium.txt              1000              311000
# 20           food_list_small.txt               100              101000
# 21           food_list_small.txt              1000              101000
# 22          food_list_medium.txt               100              311000
# 23          food_list_medium.txt              1000              311000
# 24           food_list_small.txt               100              101000
# 25           food_list_small.txt              1000              101000
# 26          food_list_medium.txt               100              311000
# 27          food_list_medium.txt              1000              311000
# 28           food_list_small.txt               100              101000
# 29           food_list_small.txt              1000              101000
# 30          food_list_medium.txt               100              311000
# 31          food_list_medium.txt              1000              311000
# 32           food_list_small.txt               100              101000
# 33           food_list_small.txt              1000              101000
# 34          food_list_medium.txt               100              311000
# 35          food_list_medium.txt              1000              311000
# 36           food_list_small.txt               100              101000
# 37           food_list_small.txt              1000              101000
# 38          food_list_medium.txt               100              311000
# 39          food_list_medium.txt              1000              311000
# 40           food_list_small.txt               100              101000
# 41           food_list_small.txt              1000              101000
# 42          food_list_medium.txt               100              311000
# 43          food_list_medium.txt              1000              311000
# 44           food_list_small.txt               100              101000
# 45           food_list_small.txt              1000              101000
# 46          food_list_medium.txt               100              311000
# 47          food_list_medium.txt              1000              311000
# 48           food_list_small.txt               100              101000
# 49           food_list_small.txt              1000              101000
# 50          food_list_medium.txt               100              311000
# 51          food_list_medium.txt              1000              311000
# 52           food_list_small.txt               100              101000
# 53           food_list_small.txt              1000              101000
# 54          food_list_medium.txt               100              311000
# 55          food_list_medium.txt              1000              311000
# 56           food_list_small.txt               100              101000
# 57           food_list_small.txt              1000              101000
# 58          food_list_medium.txt               100              311000
# 59          food_list_medium.txt              1000              311000
#
#             monofact_rate  miscalibration_rate  \
# run_number
# 0                0.995000             0.452007
# 1                0.924000             0.912587
# 2                1.000000             0.437080
# 3                0.975750             0.923799
# 4                0.977500             0.447000
# 5                0.855625             0.902773
# 6                0.992500             0.460000
# 7                0.940875             0.917294
# 8                0.527500             0.271014
# 9                0.364375             0.512483
# 10               0.588750             0.300718
# 11               0.419750             0.564889
# 12               0.091250             0.296410
# 13               0.043000             0.370086
# 14               0.103750             0.270652
# 15               0.043125             0.357745
# 16               0.020000             0.693036
# 17               0.007500             0.870062
# 18               0.023750             0.761919
# 19               0.006750             0.887984
# 20               1.000000             0.454000
# 21               0.919250             0.917695
# 22               0.997500             0.448000
# 23               0.971875             0.924995
# 24               0.982500             0.453000
# 25               0.847500             0.900164
# 26               0.995000             0.460000
# 27               0.940375             0.919296
# 28               0.535000             0.282520
# 29               0.365500             0.541015
# 30               0.581250             0.290080
# 31               0.432875             0.557261
# 32               0.090000             0.296643
# 33               0.044250             0.356665
# 34               0.092500             0.301369
# 35               0.047000             0.362281
# 36               0.020000             0.768889
# 37               0.008750             0.765080
# 38               0.017500             0.758111
# 39               0.008750             0.857058
# 40               0.992500             0.462000
# 41               0.920500             0.913891
# 42               1.000000             0.463011
# 43               0.974250             0.923599
# 44               0.975000             0.474000
# 45               0.857750             0.903791
# 46               0.992500             0.460000
# 47               0.940375             0.923189
# 48               0.542500             0.275000
# 49               0.374625             0.521777
# 50               0.583750             0.298698
# 51               0.433125             0.563374
# 52               0.111250             0.272508
# 53               0.043000             0.401271
# 54               0.116250             0.314576
# 55               0.044000             0.357309
# 56               0.017500             0.730000
# 57               0.006375             0.875635
# 58               0.015000             0.712719
# 59               0.007000             0.869260
#
#             facts_to_possible_hallucinations_ratio  \
# run_number
# 0                                         0.374529
# 1                                         0.036065
# 2                                         0.375469
# 3                                         0.037045
# 4                                         0.371240
# 5                                         0.034476
# 6                                         0.374060
# 7                                         0.036281
# 8                                         0.229394
# 9                                         0.016618
# 10                                        0.247235
# 11                                        0.018550
# 12                                        0.054854
# 13                                        0.002484
# 14                                        0.058605
# 15                                        0.002508
# 16                                        0.015001
# 17                                        0.000553
# 18                                        0.017345
# 19                                        0.000511
# 20                                        0.375469
# 21                                        0.035967
# 22                                        0.374999
# 23                                        0.036975
# 24                                        0.372180
# 25                                        0.034316
# 26                                        0.374529
# 27                                        0.036304
# 28                                        0.233150
# 29                                        0.016848
# 30                                        0.246765
# 31                                        0.019070
# 32                                        0.052978
# 33                                        0.002597
# 34                                        0.052978
# 35                                        0.002738
# 36                                        0.015938
# 37                                        0.000586
# 38                                        0.015001
# 39                                        0.000600
# 40                                        0.374060
# 41                                        0.035995
# 42                                        0.375469
# 43                                        0.037022
# 44                                        0.370770
# 45                                        0.034476
# 46                                        0.374060
# 47                                        0.036323
# 48                                        0.234558
# 49                                        0.017049
# 50                                        0.250522
# 51                                        0.019004
# 52                                        0.059543
# 53                                        0.002531
# 54                                        0.060481
# 55                                        0.002578
# 56                                        0.016876
# 57                                        0.000516
# 58                                        0.016876
# 59                                        0.000539
#
#             estimated_hallucinations_rate  naive_hallucinations_rate  \
# run_number
# 0                               -0.079023                      0.027
# 1                               -0.102914                      0.157
# 2                               -0.060037                      0.028
# 3                               -0.063356                      0.197
# 4                               -0.088227                      0.026
# 5                               -0.159886                      0.165
# 6                               -0.089047                      0.035
# 7                               -0.090962                      0.206
# 8                               -0.220395                      0.010
# 9                               -0.242989                      0.083
# 10                              -0.206691                      0.017
# 11                              -0.241951                      0.130
# 12                              -0.507501                      0.002
# 13                              -0.407832                      0.005
# 14                              -0.472994                      0.003
# 15                              -0.395390                      0.003
# 16                              -0.935524                      0.000
# 17                              -0.941378                      0.001
# 18                              -1.003001                      0.000
# 19                              -0.960008                      0.000
# 20                              -0.076957                      0.046
# 21                              -0.112674                      0.191
# 22                              -0.072987                      0.025
# 23                              -0.068357                      0.203
# 24                              -0.090167                      0.031
# 25                              -0.165243                      0.172
# 26                              -0.087017                      0.040
# 27                              -0.093488                      0.215
# 28                              -0.228157                      0.009
# 29                              -0.270625                      0.075
# 30                              -0.203083                      0.017
# 31                              -0.221718                      0.124
# 32                              -0.507109                      0.001
# 33                              -0.393274                      0.011
# 34                              -0.509335                      0.000
# 35                              -0.396281                      0.014
# 36                              -1.012315                      0.000
# 37                              -0.835178                      0.000
# 38                              -1.003099                      0.000
# 39                              -0.927170                      0.000
# 40                              -0.091047                      0.024
# 41                              -0.107648                      0.164
# 42                              -0.085967                      0.045
# 43                              -0.064633                      0.189
# 44                              -0.117258                      0.027
# 45                              -0.158779                      0.185
# 46                              -0.089047                      0.035
# 47                              -0.097400                      0.225
# 48                              -0.214546                      0.021
# 49                              -0.242464                      0.069
# 50                              -0.212957                      0.019
# 51                              -0.227516                      0.116
# 52                              -0.468289                      0.001
# 53                              -0.439065                      0.005
# 54                              -0.506295                      0.000
# 55                              -0.394150                      0.007
# 56                              -0.976863                      0.000
# 57                              -0.948038                      0.000
# 58                              -0.962082                      0.000
# 59                              -0.941061                      0.001
#
#             true_hallucinations_rate
# run_number
# 0                              0.027
# 1                              0.156
# 2                              0.028
# 3                              0.197
# 4                              0.026
# 5                              0.165
# 6                              0.035
# 7                              0.205
# 8                              0.010
# 9                              0.082
# 10                             0.017
# 11                             0.129
# 12                             0.002
# 13                             0.005
# 14                             0.003
# 15                             0.003
# 16                             0.000
# 17                             0.001
# 18                             0.000
# 19                             0.000
# 20                             0.046
# 21                             0.190
# 22                             0.025
# 23                             0.202
# 24                             0.031
# 25                             0.170
# 26                             0.040
# 27                             0.214
# 28                             0.009
# 29                             0.074
# 30                             0.017
# 31                             0.124
# 32                             0.001
# 33                             0.011
# 34                             0.000
# 35                             0.014
# 36                             0.000
# 37                             0.000
# 38                             0.000
# 39                             0.000
# 40                             0.024
# 41                             0.163
# 42                             0.045
# 43                             0.188
# 44                             0.027
# 45                             0.184
# 46                             0.035
# 47                             0.224
# 48                             0.021
# 49                             0.069
# 50                             0.019
# 51                             0.116
# 52                             0.001
# 53                             0.005
# 54                             0.000
# 55                             0.007
# 56                             0.000
# 57                             0.000
# 58                             0.000
# 59                             0.001

# %%
merged_results_df.sort_values(by=["seed","training_size","possibilities_size"], ascending=True)
# Out:
#             seed  zipf_alpha  training_size  true_dist_size  \
# run_number
# 20            15         0.1            800            1000
# 24            15         0.5            800            1000
# 28            15         1.0            800            1000
# 32            15         1.5            800            1000
# 36            15         2.0            800            1000
# 22            15         0.1            800            1000
# 26            15         0.5            800            1000
# 30            15         1.0            800            1000
# 34            15         1.5            800            1000
# 38            15         2.0            800            1000
# 21            15         0.1           8000           10000
# 25            15         0.5           8000           10000
# 29            15         1.0           8000           10000
# 33            15         1.5           8000           10000
# 37            15         2.0           8000           10000
# 23            15         0.1           8000           10000
# 27            15         0.5           8000           10000
# 31            15         1.0           8000           10000
# 35            15         1.5           8000           10000
# 39            15         2.0           8000           10000
# 0             42         0.1            800            1000
# 4             42         0.5            800            1000
# 8             42         1.0            800            1000
# 12            42         1.5            800            1000
# 16            42         2.0            800            1000
# 2             42         0.1            800            1000
# 6             42         0.5            800            1000
# 10            42         1.0            800            1000
# 14            42         1.5            800            1000
# 18            42         2.0            800            1000
# 1             42         0.1           8000           10000
# 5             42         0.5           8000           10000
# 9             42         1.0           8000           10000
# 13            42         1.5           8000           10000
# 17            42         2.0           8000           10000
# 3             42         0.1           8000           10000
# 7             42         0.5           8000           10000
# 11            42         1.0           8000           10000
# 15            42         1.5           8000           10000
# 19            42         2.0           8000           10000
# 40           102         0.1            800            1000
# 44           102         0.5            800            1000
# 48           102         1.0            800            1000
# 52           102         1.5            800            1000
# 56           102         2.0            800            1000
# 42           102         0.1            800            1000
# 46           102         0.5            800            1000
# 50           102         1.0            800            1000
# 54           102         1.5            800            1000
# 58           102         2.0            800            1000
# 41           102         0.1           8000           10000
# 45           102         0.5           8000           10000
# 49           102         1.0           8000           10000
# 53           102         1.5           8000           10000
# 57           102         2.0           8000           10000
# 43           102         0.1           8000           10000
# 47           102         0.5           8000           10000
# 51           102         1.0           8000           10000
# 55           102         1.5           8000           10000
# 59           102         2.0           8000           10000
#
#                   food_list_name  number_of_person  possibilities_size  \
# run_number
# 20           food_list_small.txt               100              101000
# 24           food_list_small.txt               100              101000
# 28           food_list_small.txt               100              101000
# 32           food_list_small.txt               100              101000
# 36           food_list_small.txt               100              101000
# 22          food_list_medium.txt               100              311000
# 26          food_list_medium.txt               100              311000
# 30          food_list_medium.txt               100              311000
# 34          food_list_medium.txt               100              311000
# 38          food_list_medium.txt               100              311000
# 21           food_list_small.txt              1000              101000
# 25           food_list_small.txt              1000              101000
# 29           food_list_small.txt              1000              101000
# 33           food_list_small.txt              1000              101000
# 37           food_list_small.txt              1000              101000
# 23          food_list_medium.txt              1000              311000
# 27          food_list_medium.txt              1000              311000
# 31          food_list_medium.txt              1000              311000
# 35          food_list_medium.txt              1000              311000
# 39          food_list_medium.txt              1000              311000
# 0            food_list_small.txt               100              101000
# 4            food_list_small.txt               100              101000
# 8            food_list_small.txt               100              101000
# 12           food_list_small.txt               100              101000
# 16           food_list_small.txt               100              101000
# 2           food_list_medium.txt               100              311000
# 6           food_list_medium.txt               100              311000
# 10          food_list_medium.txt               100              311000
# 14          food_list_medium.txt               100              311000
# 18          food_list_medium.txt               100              311000
# 1            food_list_small.txt              1000              101000
# 5            food_list_small.txt              1000              101000
# 9            food_list_small.txt              1000              101000
# 13           food_list_small.txt              1000              101000
# 17           food_list_small.txt              1000              101000
# 3           food_list_medium.txt              1000              311000
# 7           food_list_medium.txt              1000              311000
# 11          food_list_medium.txt              1000              311000
# 15          food_list_medium.txt              1000              311000
# 19          food_list_medium.txt              1000              311000
# 40           food_list_small.txt               100              101000
# 44           food_list_small.txt               100              101000
# 48           food_list_small.txt               100              101000
# 52           food_list_small.txt               100              101000
# 56           food_list_small.txt               100              101000
# 42          food_list_medium.txt               100              311000
# 46          food_list_medium.txt               100              311000
# 50          food_list_medium.txt               100              311000
# 54          food_list_medium.txt               100              311000
# 58          food_list_medium.txt               100              311000
# 41           food_list_small.txt              1000              101000
# 45           food_list_small.txt              1000              101000
# 49           food_list_small.txt              1000              101000
# 53           food_list_small.txt              1000              101000
# 57           food_list_small.txt              1000              101000
# 43          food_list_medium.txt              1000              311000
# 47          food_list_medium.txt              1000              311000
# 51          food_list_medium.txt              1000              311000
# 55          food_list_medium.txt              1000              311000
# 59          food_list_medium.txt              1000              311000
#
#             monofact_rate  miscalibration_rate  \
# run_number
# 20               1.000000             0.454000
# 24               0.982500             0.453000
# 28               0.535000             0.282520
# 32               0.090000             0.296643
# 36               0.020000             0.768889
# 22               0.997500             0.448000
# 26               0.995000             0.460000
# 30               0.581250             0.290080
# 34               0.092500             0.301369
# 38               0.017500             0.758111
# 21               0.919250             0.917695
# 25               0.847500             0.900164
# 29               0.365500             0.541015
# 33               0.044250             0.356665
# 37               0.008750             0.765080
# 23               0.971875             0.924995
# 27               0.940375             0.919296
# 31               0.432875             0.557261
# 35               0.047000             0.362281
# 39               0.008750             0.857058
# 0                0.995000             0.452007
# 4                0.977500             0.447000
# 8                0.527500             0.271014
# 12               0.091250             0.296410
# 16               0.020000             0.693036
# 2                1.000000             0.437080
# 6                0.992500             0.460000
# 10               0.588750             0.300718
# 14               0.103750             0.270652
# 18               0.023750             0.761919
# 1                0.924000             0.912587
# 5                0.855625             0.902773
# 9                0.364375             0.512483
# 13               0.043000             0.370086
# 17               0.007500             0.870062
# 3                0.975750             0.923799
# 7                0.940875             0.917294
# 11               0.419750             0.564889
# 15               0.043125             0.357745
# 19               0.006750             0.887984
# 40               0.992500             0.462000
# 44               0.975000             0.474000
# 48               0.542500             0.275000
# 52               0.111250             0.272508
# 56               0.017500             0.730000
# 42               1.000000             0.463011
# 46               0.992500             0.460000
# 50               0.583750             0.298698
# 54               0.116250             0.314576
# 58               0.015000             0.712719
# 41               0.920500             0.913891
# 45               0.857750             0.903791
# 49               0.374625             0.521777
# 53               0.043000             0.401271
# 57               0.006375             0.875635
# 43               0.974250             0.923599
# 47               0.940375             0.923189
# 51               0.433125             0.563374
# 55               0.044000             0.357309
# 59               0.007000             0.869260
#
#             facts_to_possible_hallucinations_ratio  \
# run_number
# 20                                        0.375469
# 24                                        0.372180
# 28                                        0.233150
# 32                                        0.052978
# 36                                        0.015938
# 22                                        0.374999
# 26                                        0.374529
# 30                                        0.246765
# 34                                        0.052978
# 38                                        0.015001
# 21                                        0.035967
# 25                                        0.034316
# 29                                        0.016848
# 33                                        0.002597
# 37                                        0.000586
# 23                                        0.036975
# 27                                        0.036304
# 31                                        0.019070
# 35                                        0.002738
# 39                                        0.000600
# 0                                         0.374529
# 4                                         0.371240
# 8                                         0.229394
# 12                                        0.054854
# 16                                        0.015001
# 2                                         0.375469
# 6                                         0.374060
# 10                                        0.247235
# 14                                        0.058605
# 18                                        0.017345
# 1                                         0.036065
# 5                                         0.034476
# 9                                         0.016618
# 13                                        0.002484
# 17                                        0.000553
# 3                                         0.037045
# 7                                         0.036281
# 11                                        0.018550
# 15                                        0.002508
# 19                                        0.000511
# 40                                        0.374060
# 44                                        0.370770
# 48                                        0.234558
# 52                                        0.059543
# 56                                        0.016876
# 42                                        0.375469
# 46                                        0.374060
# 50                                        0.250522
# 54                                        0.060481
# 58                                        0.016876
# 41                                        0.035995
# 45                                        0.034476
# 49                                        0.017049
# 53                                        0.002531
# 57                                        0.000516
# 43                                        0.037022
# 47                                        0.036323
# 51                                        0.019004
# 55                                        0.002578
# 59                                        0.000539
#
#             estimated_hallucinations_rate  naive_hallucinations_rate  \
# run_number
# 20                              -0.076957                      0.046
# 24                              -0.090167                      0.031
# 28                              -0.228157                      0.009
# 32                              -0.507109                      0.001
# 36                              -1.012315                      0.000
# 22                              -0.072987                      0.025
# 26                              -0.087017                      0.040
# 30                              -0.203083                      0.017
# 34                              -0.509335                      0.000
# 38                              -1.003099                      0.000
# 21                              -0.112674                      0.191
# 25                              -0.165243                      0.172
# 29                              -0.270625                      0.075
# 33                              -0.393274                      0.011
# 37                              -0.835178                      0.000
# 23                              -0.068357                      0.203
# 27                              -0.093488                      0.215
# 31                              -0.221718                      0.124
# 35                              -0.396281                      0.014
# 39                              -0.927170                      0.000
# 0                               -0.079023                      0.027
# 4                               -0.088227                      0.026
# 8                               -0.220395                      0.010
# 12                              -0.507501                      0.002
# 16                              -0.935524                      0.000
# 2                               -0.060037                      0.028
# 6                               -0.089047                      0.035
# 10                              -0.206691                      0.017
# 14                              -0.472994                      0.003
# 18                              -1.003001                      0.000
# 1                               -0.102914                      0.157
# 5                               -0.159886                      0.165
# 9                               -0.242989                      0.083
# 13                              -0.407832                      0.005
# 17                              -0.941378                      0.001
# 3                               -0.063356                      0.197
# 7                               -0.090962                      0.206
# 11                              -0.241951                      0.130
# 15                              -0.395390                      0.003
# 19                              -0.960008                      0.000
# 40                              -0.091047                      0.024
# 44                              -0.117258                      0.027
# 48                              -0.214546                      0.021
# 52                              -0.468289                      0.001
# 56                              -0.976863                      0.000
# 42                              -0.085967                      0.045
# 46                              -0.089047                      0.035
# 50                              -0.212957                      0.019
# 54                              -0.506295                      0.000
# 58                              -0.962082                      0.000
# 41                              -0.107648                      0.164
# 45                              -0.158779                      0.185
# 49                              -0.242464                      0.069
# 53                              -0.439065                      0.005
# 57                              -0.948038                      0.000
# 43                              -0.064633                      0.189
# 47                              -0.097400                      0.225
# 51                              -0.227516                      0.116
# 55                              -0.394150                      0.007
# 59                              -0.941061                      0.001
#
#             true_hallucinations_rate
# run_number
# 20                             0.046
# 24                             0.031
# 28                             0.009
# 32                             0.001
# 36                             0.000
# 22                             0.025
# 26                             0.040
# 30                             0.017
# 34                             0.000
# 38                             0.000
# 21                             0.190
# 25                             0.170
# 29                             0.074
# 33                             0.011
# 37                             0.000
# 23                             0.202
# 27                             0.214
# 31                             0.124
# 35                             0.014
# 39                             0.000
# 0                              0.027
# 4                              0.026
# 8                              0.010
# 12                             0.002
# 16                             0.000
# 2                              0.028
# 6                              0.035
# 10                             0.017
# 14                             0.003
# 18                             0.000
# 1                              0.156
# 5                              0.165
# 9                              0.082
# 13                             0.005
# 17                             0.001
# 3                              0.197
# 7                              0.205
# 11                             0.129
# 15                             0.003
# 19                             0.000
# 40                             0.024
# 44                             0.027
# 48                             0.021
# 52                             0.001
# 56                             0.000
# 42                             0.045
# 46                             0.035
# 50                             0.019
# 54                             0.000
# 58                             0.000
# 41                             0.163
# 45                             0.184
# 49                             0.069
# 53                             0.005
# 57                             0.000
# 43                             0.188
# 47                             0.224
# 51                             0.116
# 55                             0.007
# 59                             0.001

# %%
numeric_df = merged_results_df[merged_results_df.select_dtypes(["number"]).columns]

# %%
group_1 = numeric_df.groupby(["training_size","zipf_alpha","possibilities_size"])

# %%
grouped_results = group_1.agg(['mean', 'std'])

# %%
grouped_results
# Out:
#                                              seed            true_dist_size  \
#                                              mean        std           mean
# training_size zipf_alpha possibilities_size
# 800           0.1        101000              53.0  44.530888         1000.0
#                          311000              53.0  44.530888         1000.0
#               0.5        101000              53.0  44.530888         1000.0
#                          311000              53.0  44.530888         1000.0
#               1.0        101000              53.0  44.530888         1000.0
#                          311000              53.0  44.530888         1000.0
#               1.5        101000              53.0  44.530888         1000.0
#                          311000              53.0  44.530888         1000.0
#               2.0        101000              53.0  44.530888         1000.0
#                          311000              53.0  44.530888         1000.0
# 8000          0.1        101000              53.0  44.530888        10000.0
#                          311000              53.0  44.530888        10000.0
#               0.5        101000              53.0  44.530888        10000.0
#                          311000              53.0  44.530888        10000.0
#               1.0        101000              53.0  44.530888        10000.0
#                          311000              53.0  44.530888        10000.0
#               1.5        101000              53.0  44.530888        10000.0
#                          311000              53.0  44.530888        10000.0
#               2.0        101000              53.0  44.530888        10000.0
#                          311000              53.0  44.530888        10000.0
#
#                                                  number_of_person       \
#                                              std             mean  std
# training_size zipf_alpha possibilities_size
# 800           0.1        101000              0.0            100.0  0.0
#                          311000              0.0            100.0  0.0
#               0.5        101000              0.0            100.0  0.0
#                          311000              0.0            100.0  0.0
#               1.0        101000              0.0            100.0  0.0
#                          311000              0.0            100.0  0.0
#               1.5        101000              0.0            100.0  0.0
#                          311000              0.0            100.0  0.0
#               2.0        101000              0.0            100.0  0.0
#                          311000              0.0            100.0  0.0
# 8000          0.1        101000              0.0           1000.0  0.0
#                          311000              0.0           1000.0  0.0
#               0.5        101000              0.0           1000.0  0.0
#                          311000              0.0           1000.0  0.0
#               1.0        101000              0.0           1000.0  0.0
#                          311000              0.0           1000.0  0.0
#               1.5        101000              0.0           1000.0  0.0
#                          311000              0.0           1000.0  0.0
#               2.0        101000              0.0           1000.0  0.0
#                          311000              0.0           1000.0  0.0
#
#                                             monofact_rate            \
#                                                      mean       std
# training_size zipf_alpha possibilities_size
# 800           0.1        101000                  0.995833  0.003819
#                          311000                  0.999167  0.001443
#               0.5        101000                  0.978333  0.003819
#                          311000                  0.993333  0.001443
#               1.0        101000                  0.535000  0.007500
#                          311000                  0.584583  0.003819
#               1.5        101000                  0.097500  0.011924
#                          311000                  0.104167  0.011880
#               2.0        101000                  0.019167  0.001443
#                          311000                  0.018750  0.004507
# 8000          0.1        101000                  0.921250  0.002462
#                          311000                  0.973958  0.001954
#               0.5        101000                  0.853625  0.005410
#                          311000                  0.940542  0.000289
#               1.0        101000                  0.368167  0.005621
#                          311000                  0.428583  0.007651
#               1.5        101000                  0.043417  0.000722
#                          311000                  0.044708  0.002032
#               2.0        101000                  0.007542  0.001188
#                          311000                  0.007500  0.001090
#
#                                             miscalibration_rate                \
#                                                            mean           std
# training_size zipf_alpha possibilities_size
# 800           0.1        101000                        0.456002  5.289011e-03
#                          311000                        0.449364  1.301891e-02
#               0.5        101000                        0.458000  1.417745e-02
#                          311000                        0.460000  1.110223e-16
#               1.0        101000                        0.276178  5.842764e-03
#                          311000                        0.296499  5.649897e-03
#               1.5        101000                        0.288521  1.386739e-02
#                          311000                        0.295532  2.253656e-02
#               2.0        101000                        0.730642  3.793066e-02
#                          311000                        0.744250  2.737280e-02
# 8000          0.1        101000                        0.914724  2.654156e-03
#                          311000                        0.924131  7.548523e-04
#               0.5        101000                        0.902243  1.870870e-03
#                          311000                        0.919926  2.997936e-03
#               1.0        101000                        0.525092  1.455165e-02
#                          311000                        0.561841  4.038392e-03
#               1.5        101000                        0.376007  2.288508e-02
#                          311000                        0.359112  2.753350e-03
#               2.0        101000                        0.836926  6.228283e-02
#                          311000                        0.871434  1.557768e-02
#
#                                             facts_to_possible_hallucinations_ratio  \
#                                                                               mean
# training_size zipf_alpha possibilities_size
# 800           0.1        101000                                           0.374686
#                          311000                                           0.375313
#               0.5        101000                                           0.371397
#                          311000                                           0.374216
#               1.0        101000                                           0.232367
#                          311000                                           0.248174
#               1.5        101000                                           0.055792
#                          311000                                           0.057355
#               2.0        101000                                           0.015938
#                          311000                                           0.016407
# 8000          0.1        101000                                           0.036009
#                          311000                                           0.037014
#               0.5        101000                                           0.034423
#                          311000                                           0.036303
#               1.0        101000                                           0.016838
#                          311000                                           0.018875
#               1.5        101000                                           0.002538
#                          311000                                           0.002608
#               2.0        101000                                           0.000552
#                          311000                                           0.000550
#
#                                                        \
#                                                   std
# training_size zipf_alpha possibilities_size
# 800           0.1        101000              0.000718
#                          311000              0.000271
#               0.5        101000              0.000718
#                          311000              0.000271
#               1.0        101000              0.002670
#                          311000              0.002047
#               1.5        101000              0.003381
#                          311000              0.003905
#               2.0        101000              0.000938
#                          311000              0.001240
# 8000          0.1        101000              0.000051
#                          311000              0.000036
#               0.5        101000              0.000092
#                          311000              0.000021
#               1.0        101000              0.000216
#                          311000              0.000283
#               1.5        101000              0.000057
#                          311000              0.000118
#               2.0        101000              0.000035
#                          311000              0.000046
#
#                                             estimated_hallucinations_rate  \
#                                                                      mean
# training_size zipf_alpha possibilities_size
# 800           0.1        101000                                 -0.082342
#                          311000                                 -0.072997
#               0.5        101000                                 -0.098551
#                          311000                                 -0.088370
#               1.0        101000                                 -0.221033
#                          311000                                 -0.207577
#               1.5        101000                                 -0.494300
#                          311000                                 -0.496208
#               2.0        101000                                 -0.974901
#                          311000                                 -0.989394
# 8000          0.1        101000                                 -0.107746
#                          311000                                 -0.065449
#               0.5        101000                                 -0.161303
#                          311000                                 -0.093950
#               1.0        101000                                 -0.252026
#                          311000                                 -0.230395
#               1.5        101000                                 -0.413391
#                          311000                                 -0.395274
#               2.0        101000                                 -0.908198
#                          311000                                 -0.942746
#
#                                                        \
#                                                   std
# training_size zipf_alpha possibilities_size
# 800           0.1        101000              0.007609
#                          311000              0.012965
#               0.5        101000              0.016230
#                          311000              0.001172
#               1.0        101000              0.006828
#                          311000              0.004996
#               1.5        101000              0.022527
#                          311000              0.020161
#               2.0        101000              0.038433
#                          311000              0.023653
# 8000          0.1        101000              0.004881
#                          311000              0.002598
#               0.5        101000              0.003457
#                          311000              0.003244
#               1.0        101000              0.016109
#                          311000              0.010419
#               1.5        101000              0.023396
#                          311000              0.001070
#               2.0        101000              0.063325
#                          311000              0.016484
#
#                                             naive_hallucinations_rate  \
#                                                                  mean
# training_size zipf_alpha possibilities_size
# 800           0.1        101000                              0.032333
#                          311000                              0.032667
#               0.5        101000                              0.028000
#                          311000                              0.036667
#               1.0        101000                              0.013333
#                          311000                              0.017667
#               1.5        101000                              0.001333
#                          311000                              0.001000
#               2.0        101000                              0.000000
#                          311000                              0.000000
# 8000          0.1        101000                              0.170667
#                          311000                              0.196333
#               0.5        101000                              0.174000
#                          311000                              0.215333
#               1.0        101000                              0.075667
#                          311000                              0.123333
#               1.5        101000                              0.007000
#                          311000                              0.008000
#               2.0        101000                              0.000333
#                          311000                              0.000333
#
#                                                        \
#                                                   std
# training_size zipf_alpha possibilities_size
# 800           0.1        101000              0.011930
#                          311000              0.010786
#               0.5        101000              0.002646
#                          311000              0.002887
#               1.0        101000              0.006658
#                          311000              0.001155
#               1.5        101000              0.000577
#                          311000              0.001732
#               2.0        101000              0.000000
#                          311000              0.000000
# 8000          0.1        101000              0.017954
#                          311000              0.007024
#               0.5        101000              0.010149
#                          311000              0.009504
#               1.0        101000              0.007024
#                          311000              0.007024
#               1.5        101000              0.003464
#                          311000              0.005568
#               2.0        101000              0.000577
#                          311000              0.000577
#
#                                             true_hallucinations_rate
#                                                                 mean       std
# training_size zipf_alpha possibilities_size
# 800           0.1        101000                             0.032333  0.011930
#                          311000                             0.032667  0.010786
#               0.5        101000                             0.028000  0.002646
#                          311000                             0.036667  0.002887
#               1.0        101000                             0.013333  0.006658
#                          311000                             0.017667  0.001155
#               1.5        101000                             0.001333  0.000577
#                          311000                             0.001000  0.001732
#               2.0        101000                             0.000000  0.000000
#                          311000                             0.000000  0.000000
# 8000          0.1        101000                             0.169667  0.017954
#                          311000                             0.195667  0.007095
#               0.5        101000                             0.173000  0.009849
#                          311000                             0.214333  0.009504
#               1.0        101000                             0.075000  0.006557
#                          311000                             0.123000  0.006557
#               1.5        101000                             0.007000  0.003464
#                          311000                             0.008000  0.005568
#               2.0        101000                             0.000333  0.000577
#                          311000                             0.000333  0.000577

# %%
grouped_results.columns = ['_'.join(col).strip() for col in grouped_results.columns.values]

# %%
grouped_results.reset_index(inplace=True)

# %%
plot_data_1 = grouped_results[(grouped_results['training_size'] == 800) & (grouped_results['possibilities_size'] == 101000)]

# %%
plot_data_2 = grouped_results[(grouped_results['training_size'] == 800) & (grouped_results['possibilities_size'] == 311000)]

# %%
plot_data_3 = grouped_results[(grouped_results['training_size'] == 8000) & (grouped_results['possibilities_size'] == 101000)]

# %%
plot_data_4 = grouped_results[(grouped_results['training_size'] == 8000) & (grouped_results['possibilities_size'] == 311000)]

# %%
plot_data_1
# Out:
#    training_size  zipf_alpha  possibilities_size  seed_mean   seed_std  \
# 0            800         0.1              101000       53.0  44.530888
# 2            800         0.5              101000       53.0  44.530888
# 4            800         1.0              101000       53.0  44.530888
# 6            800         1.5              101000       53.0  44.530888
# 8            800         2.0              101000       53.0  44.530888
#
#    true_dist_size_mean  true_dist_size_std  number_of_person_mean  \
# 0               1000.0                 0.0                  100.0
# 2               1000.0                 0.0                  100.0
# 4               1000.0                 0.0                  100.0
# 6               1000.0                 0.0                  100.0
# 8               1000.0                 0.0                  100.0
#
#    number_of_person_std  monofact_rate_mean  ...  miscalibration_rate_mean  \
# 0                   0.0            0.995833  ...                  0.456002
# 2                   0.0            0.978333  ...                  0.458000
# 4                   0.0            0.535000  ...                  0.276178
# 6                   0.0            0.097500  ...                  0.288521
# 8                   0.0            0.019167  ...                  0.730642
#
#    miscalibration_rate_std  facts_to_possible_hallucinations_ratio_mean  \
# 0                 0.005289                                     0.374686
# 2                 0.014177                                     0.371397
# 4                 0.005843                                     0.232367
# 6                 0.013867                                     0.055792
# 8                 0.037931                                     0.015938
#
#    facts_to_possible_hallucinations_ratio_std  \
# 0                                    0.000718
# 2                                    0.000718
# 4                                    0.002670
# 6                                    0.003381
# 8                                    0.000938
#
#    estimated_hallucinations_rate_mean  estimated_hallucinations_rate_std  \
# 0                           -0.082342                           0.007609
# 2                           -0.098551                           0.016230
# 4                           -0.221033                           0.006828
# 6                           -0.494300                           0.022527
# 8                           -0.974901                           0.038433
#
#    naive_hallucinations_rate_mean  naive_hallucinations_rate_std  \
# 0                        0.032333                       0.011930
# 2                        0.028000                       0.002646
# 4                        0.013333                       0.006658
# 6                        0.001333                       0.000577
# 8                        0.000000                       0.000000
#
#    true_hallucinations_rate_mean  true_hallucinations_rate_std
# 0                       0.032333                      0.011930
# 2                       0.028000                      0.002646
# 4                       0.013333                      0.006658
# 6                       0.001333                      0.000577
# 8                       0.000000                      0.000000
#
# [5 rows x 21 columns]

# %%
plot_data_3
# Out:
#     training_size  zipf_alpha  possibilities_size  seed_mean   seed_std  \
# 10           8000         0.1              101000       53.0  44.530888
# 12           8000         0.5              101000       53.0  44.530888
# 14           8000         1.0              101000       53.0  44.530888
# 16           8000         1.5              101000       53.0  44.530888
# 18           8000         2.0              101000       53.0  44.530888
#
#     true_dist_size_mean  true_dist_size_std  number_of_person_mean  \
# 10              10000.0                 0.0                 1000.0
# 12              10000.0                 0.0                 1000.0
# 14              10000.0                 0.0                 1000.0
# 16              10000.0                 0.0                 1000.0
# 18              10000.0                 0.0                 1000.0
#
#     number_of_person_std  monofact_rate_mean  ...  miscalibration_rate_mean  \
# 10                   0.0            0.921250  ...                  0.914724
# 12                   0.0            0.853625  ...                  0.902243
# 14                   0.0            0.368167  ...                  0.525092
# 16                   0.0            0.043417  ...                  0.376007
# 18                   0.0            0.007542  ...                  0.836926
#
#     miscalibration_rate_std  facts_to_possible_hallucinations_ratio_mean  \
# 10                 0.002654                                     0.036009
# 12                 0.001871                                     0.034423
# 14                 0.014552                                     0.016838
# 16                 0.022885                                     0.002538
# 18                 0.062283                                     0.000552
#
#     facts_to_possible_hallucinations_ratio_std  \
# 10                                    0.000051
# 12                                    0.000092
# 14                                    0.000216
# 16                                    0.000057
# 18                                    0.000035
#
#     estimated_hallucinations_rate_mean  estimated_hallucinations_rate_std  \
# 10                           -0.107746                           0.004881
# 12                           -0.161303                           0.003457
# 14                           -0.252026                           0.016109
# 16                           -0.413391                           0.023396
# 18                           -0.908198                           0.063325
#
#     naive_hallucinations_rate_mean  naive_hallucinations_rate_std  \
# 10                        0.170667                       0.017954
# 12                        0.174000                       0.010149
# 14                        0.075667                       0.007024
# 16                        0.007000                       0.003464
# 18                        0.000333                       0.000577
#
#     true_hallucinations_rate_mean  true_hallucinations_rate_std
# 10                       0.169667                      0.017954
# 12                       0.173000                      0.009849
# 14                       0.075000                      0.006557
# 16                       0.007000                      0.003464
# 18                       0.000333                      0.000577
#
# [5 rows x 21 columns]

# %%
def plot_line(ax,data_df,x_name,y_mean_name,y_std_name,color,marker, linestyle, label):
    data_df.plot(x=x_name, y=y_mean_name, marker=marker, linestyle=linestyle, ax=ax,color=color, label=label)
    ax.fill_between(data_df[x_name], 
                data_df[y_mean_name] - data_df[y_std_name], 
                data_df[y_mean_name] + data_df[y_std_name], 
                color=color, alpha=0.3)

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12, 6))

# # Plot mean for result1
# plot_data.plot(x='zipf_alpha', y='monofact_rate_mean', marker='o', linestyle='-', ax=ax, label='Result1 Mean')
# ax.fill_between(plot_data['zipf_alpha'], 
#                 plot_data['monofact_rate_mean'] - plot_data['monofact_rate_std'], 
#                 plot_data['monofact_rate_mean'] + plot_data['monofact_rate_std'], 
#                 color='blue', alpha=0.3)

# Small training size
# Small possibilities size
plot_line(ax,plot_data_1,"zipf_alpha","monofact_rate_mean","monofact_rate_std","blue",marker="o",linestyle="-",label="Small training, small possibilities size monofact rate")
plot_line(ax,plot_data_1,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","blue",marker="^",linestyle="--",label="Small training, small possibilities size hallucination rate")
# Large possibilities size
plot_line(ax,plot_data_2,"zipf_alpha","monofact_rate_mean","monofact_rate_std","green",marker="o",linestyle="-",label="Small training, large possibilities size monofact rate")
plot_line(ax,plot_data_2,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","green",marker="^",linestyle="--",label="Small training, large possibilities size hallucination rate")

# Large training size
# Small possibilities size
plot_line(ax,plot_data_3,"zipf_alpha","monofact_rate_mean","monofact_rate_std","orange",marker="o",linestyle="-",label="Large training, small possibilities size monofact rate")
plot_line(ax,plot_data_3,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","orange",marker="^",linestyle="--",label="Large training, small possibilities size hallucination rate")
# Large possibilities size 
plot_line(ax,plot_data_4,"zipf_alpha","monofact_rate_mean","monofact_rate_std","red",marker="o",linestyle="-",label="Large training, large possibilities size monofact rate")
plot_line(ax,plot_data_4,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","red",marker="^",linestyle="--",label="Large training, large possibilities size hallucination rate")


# Add labels and title
ax.set_xlabel('zipf_alpha')
ax.set_ylabel('Monofact and Hallucination rates')
ax.set_title('Monofact vs Hallucination rates by zipf_alpha')
ax.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12, 6))

# # Plot mean for result1
# plot_data.plot(x='zipf_alpha', y='monofact_rate_mean', marker='o', linestyle='-', ax=ax, label='Result1 Mean')
# ax.fill_between(plot_data['zipf_alpha'], 
#                 plot_data['monofact_rate_mean'] - plot_data['monofact_rate_std'], 
#                 plot_data['monofact_rate_mean'] + plot_data['monofact_rate_std'], 
#                 color='blue', alpha=0.3)

# Small training size
# Small possibilities size
plot_line(ax,plot_data_1,"zipf_alpha","monofact_rate_mean","monofact_rate_std","blue",marker="o",linestyle="-",label="Small training, small possibilities size monofact rate")
plot_line(ax,plot_data_1,"zipf_alpha","miscalibration_rate_mean","miscalibration_rate_std","blue",marker="^",linestyle="--",label="Small training, small possibilities size miscalibration rate")
# Large possibilities size
plot_line(ax,plot_data_2,"zipf_alpha","monofact_rate_mean","monofact_rate_std","green",marker="o",linestyle="-",label="Small training, large possibilities size monofact rate")
plot_line(ax,plot_data_2,"zipf_alpha","miscalibration_rate_mean","miscalibration_rate_std","green",marker="^",linestyle="--",label="Small training, large possibilities size miscalibration rate")

# Large training size
# Small possibilities size
plot_line(ax,plot_data_3,"zipf_alpha","monofact_rate_mean","monofact_rate_std","orange",marker="o",linestyle="-",label="Large training, small possibilities size monofact rate")
plot_line(ax,plot_data_3,"zipf_alpha","miscalibration_rate_mean","miscalibration_rate_std","orange",marker="^",linestyle="--",label="Large training, small possibilities size hallucination rate")
# Large possibilities size 
plot_line(ax,plot_data_4,"zipf_alpha","monofact_rate_mean","monofact_rate_std","red",marker="o",linestyle="-",label="Large training, large possibilities size monofact rate")
plot_line(ax,plot_data_4,"zipf_alpha","miscalibration_rate_mean","miscalibration_rate_std","red",marker="^",linestyle="--",label="Large training, large possibilities size miscalibration rate")


# Add labels and title
ax.set_xlabel('zipf_alpha')
ax.set_ylabel('Monofact and Miscalibration rates')
ax.set_title('Monofact vs Miscalibration rates by zipf_alpha')
ax.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12, 6))

# # Plot mean for result1
# plot_data.plot(x='zipf_alpha', y='monofact_rate_mean', marker='o', linestyle='-', ax=ax, label='Result1 Mean')
# ax.fill_between(plot_data['zipf_alpha'], 
#                 plot_data['monofact_rate_mean'] - plot_data['monofact_rate_std'], 
#                 plot_data['monofact_rate_mean'] + plot_data['monofact_rate_std'], 
#                 color='blue', alpha=0.3)

# Small training size
# Small possibilities size
plot_line(ax,plot_data_1,"zipf_alpha","miscalibration_rate_mean","miscalibration_rate_std","blue",marker="o",linestyle="-",label="Small training, small possibilities size miscalibration_rate rate")
plot_line(ax,plot_data_1,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","blue",marker="^",linestyle="--",label="Small training, small possibilities size hallucination rate")
# Large possibilities size
plot_line(ax,plot_data_2,"zipf_alpha","miscalibration_rate_mean","miscalibration_rate_std","green",marker="o",linestyle="-",label="Small training, large possibilities size miscalibration_rate")
plot_line(ax,plot_data_2,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","green",marker="^",linestyle="--",label="Small training, large possibilities size hallucination rate")

# Large training size
# Small possibilities size
plot_line(ax,plot_data_3,"zipf_alpha","miscalibration_rate_mean","miscalibration_rate_std","orange",marker="o",linestyle="-",label="Large training, small possibilities size miscalibration_rate")
plot_line(ax,plot_data_3,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","orange",marker="^",linestyle="--",label="Large training, small possibilities size hallucination rate")
# Large possibilities size 
plot_line(ax,plot_data_4,"zipf_alpha","miscalibration_rate_mean","miscalibration_rate_std","red",marker="o",linestyle="-",label="Large training, large possibilities size miscalibration_rate")
plot_line(ax,plot_data_4,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","red",marker="^",linestyle="--",label="Large training, large possibilities size hallucination rate")


# Add labels and title
ax.set_xlabel('zipf_alpha')
ax.set_ylabel('Miscalibration and Hallucination rates')
ax.set_title('Miscalibration vs Hallucination rates by zipf_alpha')
ax.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plot_data_5 = grouped_results

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12, 6))

# # Plot mean for result1
# plot_data.plot(x='zipf_alpha', y='monofact_rate_mean', marker='o', linestyle='-', ax=ax, label='Result1 Mean')
# ax.fill_between(plot_data['zipf_alpha'], 
#                 plot_data['monofact_rate_mean'] - plot_data['monofact_rate_std'], 
#                 plot_data['monofact_rate_mean'] + plot_data['monofact_rate_std'], 
#                 color='blue', alpha=0.3)


ax.plot(plot_data_5['monofact_rate_mean'], plot_data_5['true_hallucinations_rate_mean'], 'o')  # 'o' for scatter plot
ax.set_xlabel('Monofact rate')
ax.set_ylabel('Hallucination rate')
#plot_line(ax,plot_data_1,"zipf_alpha","true_hallucinations_rate_mean","true_hallucinations_rate_std","blue",marker="^",linestyle="--",label="Small training, small possibilities size hallucination rate")


ax.set_title('Monofact vs Hallucination rates')
ax.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Batu\AppData\Local\Temp\ipykernel_38528\3472721386.py:19: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   ax.legend()
# C:\Users\Batu\AppData\Local\Temp\ipykernel_38528\3472721386.py:20: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(figsize=(12, 6))

# # Plot mean for result1
# plot_data.plot(x='zipf_alpha', y='monofact_rate_mean', marker='o', linestyle='-', ax=ax, label='Result1 Mean')
# ax.fill_between(plot_data['zipf_alpha'], 
#                 plot_data['monofact_rate_mean'] - plot_data['monofact_rate_std'], 
#                 plot_data['monofact_rate_mean'] + plot_data['monofact_rate_std'], 
#                 color='blue', alpha=0.3)

# Small training size
# Small possibilities size
#plot_line(ax,plot_data_1,"monofact_rate_mean","monofact_rate_mean","monofact_rate_std","blue",marker="o",linestyle="-",label="Small training, small possibilities size monofact rate")
plot_line(ax,plot_data_1,"monofact_rate_mean","true_hallucinations_rate_mean","true_hallucinations_rate_std","blue",marker="^",linestyle="--",label="Small training, small possibilities size hallucination rate")
# Large possibilities size
#plot_line(ax,plot_data_2,"monofact_rate","monofact_rate_mean","monofact_rate_std","green",marker="o",linestyle="-",label="Small training, large possibilities size monofact rate")
plot_line(ax,plot_data_2,"monofact_rate_mean","true_hallucinations_rate_mean","true_hallucinations_rate_std","green",marker="^",linestyle="--",label="Small training, large possibilities size hallucination rate")

# Large training size
# Small possibilities size
#plot_line(ax,plot_data_3,"monofact_rate","monofact_rate_mean","monofact_rate_std","orange",marker="o",linestyle="-",label="Large training, small possibilities size monofact rate")
plot_line(ax,plot_data_3,"monofact_rate_mean","true_hallucinations_rate_mean","true_hallucinations_rate_std","orange",marker="^",linestyle="--",label="Large training, small possibilities size hallucination rate")
# Large possibilities size 
#plot_line(ax,plot_data_4,"monofact_rate","monofact_rate_mean","monofact_rate_std","red",marker="o",linestyle="-",label="Large training, large possibilities size monofact rate")
plot_line(ax,plot_data_4,"monofact_rate_mean","true_hallucinations_rate_mean","true_hallucinations_rate_std","red",marker="^",linestyle="--",label="Large training, large possibilities size hallucination rate")

# Add labels and title
ax.set_xlabel('Monofact Rate')
ax.set_ylabel('Hallucination rate')
ax.set_title('Monofact vs Hallucination rate')
ax.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# # Plot mean for result1
# plot_data.plot(x='zipf_alpha', y='monofact_rate_mean', marker='o', linestyle='-', ax=ax, label='Result1 Mean')
# ax.fill_between(plot_data['zipf_alpha'], 
#                 plot_data['monofact_rate_mean'] - plot_data['monofact_rate_std'], 
#                 plot_data['monofact_rate_mean'] + plot_data['monofact_rate_std'], 
#                 color='blue', alpha=0.3)

# Small training size
# Small possibilities size
#plot_line(ax,plot_data_1,"monofact_rate_mean","monofact_rate_mean","monofact_rate_std","blue",marker="o",linestyle="-",label="Small training, small possibilities size monofact rate")
plot_line(ax,plot_data_1,"monofact_rate_mean","miscalibration_rate_mean","miscalibration_rate_std","blue",marker="^",linestyle="--",label="Small training, small possibilities size hallucination rate")
# Large possibilities size
#plot_line(ax,plot_data_2,"monofact_rate","monofact_rate_mean","monofact_rate_std","green",marker="o",linestyle="-",label="Small training, large possibilities size monofact rate")
plot_line(ax,plot_data_2,"monofact_rate_mean","miscalibration_rate_mean","miscalibration_rate_std","green",marker="^",linestyle="--",label="Small training, large possibilities size hallucination rate")

# Large training size
# Small possibilities size
#plot_line(ax,plot_data_3,"monofact_rate","monofact_rate_mean","monofact_rate_std","orange",marker="o",linestyle="-",label="Large training, small possibilities size monofact rate")
plot_line(ax,plot_data_3,"monofact_rate_mean","miscalibration_rate_mean","miscalibration_rate_std","orange",marker="^",linestyle="--",label="Large training, small possibilities size hallucination rate")
# Large possibilities size 
#plot_line(ax,plot_data_4,"monofact_rate","monofact_rate_mean","monofact_rate_std","red",marker="o",linestyle="-",label="Large training, large possibilities size monofact rate")
plot_line(ax,plot_data_4,"monofact_rate_mean","miscalibration_rate_mean","miscalibration_rate_std","red",marker="^",linestyle="--",label="Large training, large possibilities size hallucination rate")

# Add labels and title
ax.set_xlabel('Monofact Rate')
ax.set_ylabel('Miscalibration rate')
ax.set_title('Monofact vs Miscalibration rate')
ax.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
plot_data_1_calibration = plot_data_1
plot_data_2_calibration = plot_data_2
plot_data_3_calibration = plot_data_3
plot_data_4_calibration = plot_data_4
plot_data_1_calibration["miscalibration_rate_mean"] = 1 - plot_data_1["miscalibration_rate_mean"]
plot_data_2_calibration["miscalibration_rate_mean"] = 1 - plot_data_2["miscalibration_rate_mean"]
plot_data_3_calibration["miscalibration_rate_mean"] = 1 - plot_data_3["miscalibration_rate_mean"]
plot_data_4_calibration["miscalibration_rate_mean"] = 1 - plot_data_4["miscalibration_rate_mean"]
# Out:
# C:\Users\Batu\AppData\Local\Temp\ipykernel_38528\3573598025.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data_1_calibration["miscalibration_rate_mean"] = 1 - plot_data_1["miscalibration_rate_mean"]
# C:\Users\Batu\AppData\Local\Temp\ipykernel_38528\3573598025.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data_2_calibration["miscalibration_rate_mean"] = 1 - plot_data_2["miscalibration_rate_mean"]
# C:\Users\Batu\AppData\Local\Temp\ipykernel_38528\3573598025.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data_3_calibration["miscalibration_rate_mean"] = 1 - plot_data_3["miscalibration_rate_mean"]
# C:\Users\Batu\AppData\Local\Temp\ipykernel_38528\3573598025.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   plot_data_4_calibration["miscalibration_rate_mean"] = 1 - plot_data_4["miscalibration_rate_mean"]

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# # Plot mean for result1
# plot_data.plot(x='zipf_alpha', y='monofact_rate_mean', marker='o', linestyle='-', ax=ax, label='Result1 Mean')
# ax.fill_between(plot_data['zipf_alpha'], 
#                 plot_data['monofact_rate_mean'] - plot_data['monofact_rate_std'], 
#                 plot_data['monofact_rate_mean'] + plot_data['monofact_rate_std'], 
#                 color='blue', alpha=0.3)

# Small training size
# Small possibilities size
#plot_line(ax,plot_data_1,"monofact_rate_mean","monofact_rate_mean","monofact_rate_std","blue",marker="o",linestyle="-",label="Small training, small possibilities size monofact rate")
plot_line(ax,plot_data_1_calibration,"monofact_rate_mean","miscalibration_rate_mean","miscalibration_rate_std","blue",marker="^",linestyle="--",label="Small training, small possibilities size hallucination rate")
# Large possibilities size
#plot_line(ax,plot_data_2,"monofact_rate","monofact_rate_mean","monofact_rate_std","green",marker="o",linestyle="-",label="Small training, large possibilities size monofact rate")
plot_line(ax,plot_data_2_calibration,"monofact_rate_mean","miscalibration_rate_mean","miscalibration_rate_std","green",marker="^",linestyle="--",label="Small training, large possibilities size hallucination rate")

# Large training size
# Small possibilities size
#plot_line(ax,plot_data_3,"monofact_rate","monofact_rate_mean","monofact_rate_std","orange",marker="o",linestyle="-",label="Large training, small possibilities size monofact rate")
plot_line(ax,plot_data_3_calibration,"monofact_rate_mean","miscalibration_rate_mean","miscalibration_rate_std","orange",marker="^",linestyle="--",label="Large training, small possibilities size hallucination rate")
# Large possibilities size 
#plot_line(ax,plot_data_4,"monofact_rate","monofact_rate_mean","monofact_rate_std","red",marker="o",linestyle="-",label="Large training, large possibilities size monofact rate")
plot_line(ax,plot_data_4_calibration,"monofact_rate_mean","miscalibration_rate_mean","miscalibration_rate_std","red",marker="^",linestyle="--",label="Large training, large possibilities size hallucination rate")

# Add labels and title
ax.set_xlabel('Monofact Rate')
ax.set_ylabel('Calibration rate')
ax.set_title('Monofact vs Calibration rate')
ax.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots(figsize=(12, 6))

# # Plot mean for result1
# plot_data.plot(x='zipf_alpha', y='monofact_rate_mean', marker='o', linestyle='-', ax=ax, label='Result1 Mean')
# ax.fill_between(plot_data['zipf_alpha'], 
#                 plot_data['monofact_rate_mean'] - plot_data['monofact_rate_std'], 
#                 plot_data['monofact_rate_mean'] + plot_data['monofact_rate_std'], 
#                 color='blue', alpha=0.3)

# Small training size
# Small possibilities size
#plot_line(ax,plot_data_1,"monofact_rate_mean","monofact_rate_mean","monofact_rate_std","blue",marker="o",linestyle="-",label="Small training, small possibilities size monofact rate")
plot_line(ax,plot_data_1,"miscalibration_rate_mean","true_hallucinations_rate_mean","true_hallucinations_rate_std","blue",marker="^",linestyle="--",label="Small training, small possibilities size hallucination rate")
# Large possibilities size
#plot_line(ax,plot_data_2,"monofact_rate","monofact_rate_mean","monofact_rate_std","green",marker="o",linestyle="-",label="Small training, large possibilities size monofact rate")
plot_line(ax,plot_data_2,"miscalibration_rate_mean","true_hallucinations_rate_mean","true_hallucinations_rate_std","green",marker="^",linestyle="--",label="Small training, large possibilities size hallucination rate")

# Large training size
# Small possibilities size
#plot_line(ax,plot_data_3,"monofact_rate","monofact_rate_mean","monofact_rate_std","orange",marker="o",linestyle="-",label="Large training, small possibilities size monofact rate")
plot_line(ax,plot_data_3,"miscalibration_rate_mean","true_hallucinations_rate_mean","true_hallucinations_rate_std","orange",marker="^",linestyle="--",label="Large training, small possibilities size hallucination rate")
# Large possibilities size 
#plot_line(ax,plot_data_4,"monofact_rate","monofact_rate_mean","monofact_rate_std","red",marker="o",linestyle="-",label="Large training, large possibilities size monofact rate")
plot_line(ax,plot_data_4,"miscalibration_rate_mean","true_hallucinations_rate_mean","true_hallucinations_rate_std","red",marker="^",linestyle="--",label="Large training, large possibilities size hallucination rate")

# Add labels and title
ax.set_xlabel('Miscalibration Rate')
ax.set_ylabel('Hallucination rate')
ax.set_title('Miscalibration vs Hallucination rate')
ax.legend()
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
